# %%
from pathlib import Path
import asyncio
import pandas as pd
root_path = Path.cwd().parent

from stables.data.defillama_api import DeFiLlamaAPI
from stables.transform.defillama_transform import DeFiLlamaTransformer
from stables.visualization.components import plot_stable_chain_data

# %%
defillama_api = DeFiLlamaAPI()

crvusd_data = defillama_api.fetch_stable(id=110)
crvusd_df = DeFiLlamaTransformer.stable_to_df(crvusd_data)

# %%
crvusd_df
# Out:
#           date   circulating     bridgedTo  \
# 0   2024-02-13  2.756400e+04  2.756400e+04
# 1   2024-02-14  9.940260e+05  9.940260e+05
# 2   2024-02-15  1.755450e+06  1.755450e+06
# 3   2024-02-16  1.755450e+06  1.755450e+06
# 4   2024-02-17  2.005702e+06  2.005702e+06
# ..         ...           ...           ...
# 672 2025-05-10  4.591914e+06  4.591914e+06
# 673 2025-05-11  4.591914e+06  4.591914e+06
# 674 2025-05-12  4.591914e+06  4.591914e+06
# 675 2025-05-13  4.591914e+06  4.591914e+06
# 676 2025-05-14  4.591914e+06  4.591914e+06
#
#      bridgedTo_bridges_not-found_not-found_amount  minted     chain  \
# 0                                    2.756400e+04     NaN  Optimism
# 1                                    9.940260e+05     NaN  Optimism
# 2                                    1.755450e+06     NaN  Optimism
# 3                                    1.755450e+06     NaN  Optimism
# 4                                    2.005702e+06     NaN  Optimism
# ..                                            ...     ...       ...
# 672                                  4.591914e+06     NaN  Arbitrum
# 673                                  4.591914e+06     NaN  Arbitrum
# 674                                  4.591914e+06     NaN  Arbitrum
# 675                                  4.591914e+06     NaN  Arbitrum
# 676                                  4.591914e+06     NaN  Arbitrum
#
#       peg_type  bridgedTo_bridges_not-found_ethereum_amount
# 0    peggedUSD                                          NaN
# 1    peggedUSD                                          NaN
# 2    peggedUSD                                          NaN
# 3    peggedUSD                                          NaN
# 4    peggedUSD                                          NaN
# ..         ...                                          ...
# 672  peggedUSD                                          NaN
# 673  peggedUSD                                          NaN
# 674  peggedUSD                                          NaN
# 675  peggedUSD                                          NaN
# 676  peggedUSD                                          NaN
#
# [5163 rows x 8 columns]

# %%
# Custom usage example
fig = plot_stable_chain_data(
    df=crvusd_df[crvusd_df['chain'] != 'Ethereum'],
    value_columns=[
        {'column': 'circulating', 'name': 'Circulating', 'line_style': {'width': 2}},
        # {'column': 'bridgedTo', 'name': 'Bridged To', 'line_style': {'width': 2, 'dash': 'dash'}}
        # {'column': 'minted', 'name': 'Minted', 'line_style': {'width': 2, 'dash': 'dot'}}
    ],
    title='CRVUSD Over Time by Chain',
    template='plotly_white'
)
fig.show()

# %%
# Custom usage example
fig = plot_stable_chain_data(
    df=crvusd_df,
    value_columns=[
        {'column': 'circulating', 'name': 'Circulating', 'line_style': {'width': 2}},
        # {'column': 'bridgedTo', 'name': 'Bridged To', 'line_style': {'width': 2, 'dash': 'dash'}}
    ],
    title='CRVUSD Over Time by Chain',
    template='plotly_white'
)
fig.show()
