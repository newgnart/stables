# %%
from pathlib import Path
import asyncio
import pandas as pd
root_path = Path.cwd().parent

from stables.data.defillama_api import DeFiLlamaAPI
from stables.transform.defillama_transform import DeFiLlamaTransformer
from stables.visualization.components import plot_stable_chain_data
from stables.analysis.Yield import Yield

# %% [markdown]
# # supply

# %%
df = pd.read_csv(root_path / "data/processed/stable_110.csv")
df
# Out:
#             date   circulating     bridgedTo  \
# 0     2024-02-13  2.756400e+04  2.756400e+04
# 1     2024-02-14  9.940260e+05  9.940260e+05
# 2     2024-02-15  1.755450e+06  1.755450e+06
# 3     2024-02-16  1.755450e+06  1.755450e+06
# 4     2024-02-17  2.005702e+06  2.005702e+06
# ...          ...           ...           ...
# 5169  2025-05-11  4.591914e+06  4.591914e+06
# 5170  2025-05-12  4.591914e+06  4.591914e+06
# 5171  2025-05-13  4.591914e+06  4.591914e+06
# 5172  2025-05-14  4.591914e+06  4.591914e+06
# 5173  2025-05-15  4.591914e+06  4.591914e+06
#
#       bridgedTo_bridges_not-found_not-found_amount  minted     chain  \
# 0                                     2.756400e+04     NaN  Optimism
# 1                                     9.940260e+05     NaN  Optimism
# 2                                     1.755450e+06     NaN  Optimism
# 3                                     1.755450e+06     NaN  Optimism
# 4                                     2.005702e+06     NaN  Optimism
# ...                                            ...     ...       ...
# 5169                                  4.591914e+06     NaN  Arbitrum
# 5170                                  4.591914e+06     NaN  Arbitrum
# 5171                                  4.591914e+06     NaN  Arbitrum
# 5172                                  4.591914e+06     NaN  Arbitrum
# 5173                                  4.591914e+06     NaN  Arbitrum
#
#        peg_type  bridgedTo_bridges_not-found_ethereum_amount
# 0     peggedUSD                                          NaN
# 1     peggedUSD                                          NaN
# 2     peggedUSD                                          NaN
# 3     peggedUSD                                          NaN
# 4     peggedUSD                                          NaN
# ...         ...                                          ...
# 5169  peggedUSD                                          NaN
# 5170  peggedUSD                                          NaN
# 5171  peggedUSD                                          NaN
# 5172  peggedUSD                                          NaN
# 5173  peggedUSD                                          NaN
#
# [5174 rows x 8 columns]

# %%
# Custom usage example
fig = plot_stable_chain_data(
    df=df[df['chain'] != 'Ethereum'],
    value_columns=[
        {'column': 'circulating', 'name': 'Circulating', 'line_style': {'width': 2}},
        # {'column': 'bridgedTo', 'name': 'Bridged To', 'line_style': {'width': 2, 'dash': 'dash'}}
        # {'column': 'minted', 'name': 'Minted', 'line_style': {'width': 2, 'dash': 'dot'}}
    ],
    title='CRVUSD Over Time by Chain',
    template='plotly_white'
)
fig.show()

# %%
# Custom usage example
fig = plot_stable_chain_data(
    df=df,
    value_columns=[
        {'column': 'circulating', 'name': 'Circulating', 'line_style': {'width': 2}},
        # {'column': 'bridgedTo', 'name': 'Bridged To', 'line_style': {'width': 2, 'dash': 'dash'}}
    ],
    title='CRVUSD Over Time by Chain',
    template='plotly_white'
)
fig.show()

# %% [markdown]
# # yield

# %%
df = pd.read_csv(root_path / "data/processed/yield_pools.csv")
print(df.shape)
df.head()
# Out:
# (19737, 28)
#       chain             project symbol       tvlUsd  apyBase  apyReward  \
# 0  Ethereum                lido  STETH  23205854850  2.81300        NaN
# 1  Ethereum      ether.fi-stake  WEETH   6004779504  2.93241    0.52638
# 2  Ethereum  binance-staked-eth  WBETH   5407095779  2.49295        NaN
# 3  Ethereum             aave-v3  WEETH   4357933178  0.00058        NaN
# 4  Ethereum             aave-v3   WBTC   3987427269  0.01998        NaN
#
#        apy                                    rewardTokens  \
# 0  2.81300                                             NaN
# 1  3.45879  ['0x8F08B70456eb22f6109F57b8fafE862ED28E6040']
# 2  2.49295                                             NaN
# 3  0.00058                                             NaN
# 4  0.01998                                             NaN
#
#                                    pool  apyPct1D  ...    sigma  count  \
# 0  747c1d2a-c668-4682-b9f9-296708a3dd90  -0.08900  ...  0.05233   1079
# 1  46bd2bdf-6d92-4066-b482-e885ee172264  -0.25648  ...  0.04396    345
# 2  80b8bf92-b953-4c20-98ea-c9653ef2bb98  -0.21791  ...  0.03141    698
# 3  db678df9-3281-4bc2-a8bb-01160ffd6d48  -0.00001  ...  0.00851    397
# 4  7e382157-b1bc-406d-b17b-facba43b716e   0.00011  ...  0.00653    827
#
#    outlier                                underlyingTokens il7d apyBase7d  \
# 0    False  ['0x0000000000000000000000000000000000000000']  NaN       NaN
# 1    False  ['0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2']  NaN   2.84198
# 2    False  ['0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2']  NaN       NaN
# 3    False  ['0xCd5fE23C85820F7B72D0926FC9b05b43E359b7ee']  NaN       NaN
# 4    False  ['0x2260FAC5E5542a773Aa44fBCfeDf7C193bc2C599']  NaN       NaN
#
#   apyMean30d  volumeUsd1d  volumeUsd7d  apyBaseInception
# 0    2.82969          NaN          NaN               NaN
# 1    3.45053          NaN          NaN               NaN
# 2    2.57262          NaN          NaN               NaN
# 3    0.00061          NaN          NaN               NaN
# 4    0.02405          NaN          NaN               NaN
#
# [5 rows x 28 columns]

# %%
cols = ['chain', 'symbol', 'ilRisk', 'apy', 'apyBase', 'pool']
df[cols].describe(include='all')
# Out:
#            chain symbol ilRisk            apy        apyBase  \
# count      19737  19721  19737   19737.000000   16931.000000
# unique       106  12223      2            NaN            NaN
# top     Ethereum   USDC    yes            NaN            NaN
# freq        4905    317  14189            NaN            NaN
# mean         NaN    NaN    NaN     239.938194     194.768970
# std          NaN    NaN    NaN    8979.414283    6762.915739
# min          NaN    NaN    NaN       0.000000       0.000000
# 25%          NaN    NaN    NaN       0.024000       0.019305
# 50%          NaN    NaN    NaN       4.418370       3.131040
# 75%          NaN    NaN    NaN      25.403260      23.396105
# max          NaN    NaN    NaN  866871.893730  732254.680580
#
#                                         pool
# count                                  19737
# unique                                 19737
# top     747c1d2a-c668-4682-b9f9-296708a3dd90
# freq                                       1
# mean                                     NaN
# std                                      NaN
# min                                      NaN
# 25%                                      NaN
# 50%                                      NaN
# 75%                                      NaN
# max                                      NaN

# %%
stable_yield_bearing_list = [
    'SCRVUSD', 'SUSDS', 'SUSDE', 'USDY', 'FXSAVE'
]

# %%
df_stable_yield_bearing = df[df['symbol'].isin(stable_yield_bearing_list)]
df_stable_yield_bearing.shape
# Out:
# (57, 28)

# %% [markdown]
# # SCRVUSD
# - equal means single pool, ilRisk=="no" probably. .contains("SCRVUSD") would result more (e.g. LP yield)

# %% [markdown]
# ## on curve

# %%
df = pd.read_csv(root_path / "data/processed/yield_pools.csv")
y = Yield("SCRVUSD", "5fd328af-4203-471b-bd16-1705c726d926", llama_yield_data=df)

# %%
for attr in y.yield_attributes():
    print(f"{attr}: {y[attr]}")
# Out:
# chain: Ethereum
# project: crvusd
# symbol: SCRVUSD
# tvlUsd: 38130771
# apyBase: 1.53794
# apyReward: nan
# apy: 1.53794
# rewardTokens: nan
# pool: 5fd328af-4203-471b-bd16-1705c726d926
# apyPct1D: 0.36297
# apyPct7D: 0.22438
# apyPct30D: -0.93552
# stablecoin: False
# ilRisk: no
# exposure: single
# predictions: {'predictedClass': 'Stable/Up', 'predictedProbability': 81, 'binnedConfidence': 3}
# poolMeta: nan
# mu: 7.16448
# sigma: 0.28971
# count: 183
# outlier: False
# underlyingTokens: nan
# il7d: nan
# apyBase7d: nan
# apyMean30d: 1.23906
# volumeUsd1d: nan
# volumeUsd7d: nan
# apyBaseInception: nan

# %%
df = pd.read_csv(root_path / "data/processed/yield_pools.csv")
df = df[df['symbol'] == 'SCRVUSD']
df
# Out:
#           chain     project   symbol    tvlUsd       apyBase  apyReward  \
# 302    Ethereum      crvusd  SCRVUSD  38130771       1.53794        NaN
# 7164   Ethereum      pendle  SCRVUSD    198987       8.40857        NaN
# 7165   Ethereum      pendle  SCRVUSD    198987       2.99519    1.27492
# 7199   Ethereum  spectra-v2  SCRVUSD    196612  732254.68058        NaN
# 7200   Ethereum  spectra-v2  SCRVUSD    196612  469060.56206    0.01074
# 7878   Ethereum      napier  SCRVUSD    161963       7.60121    0.00000
# 8698   Ethereum      napier  SCRVUSD    133984       0.00000    0.00000
# 13605  Ethereum    stakedao  SCRVUSD     43886       3.05949    0.00000
#
#                 apy                                    rewardTokens  \
# 302         1.53794                                             NaN
# 7164        8.40857                                             NaN
# 7165        4.27011  ['0x808507121b80c02388fad14726482e061b8da827']
# 7199   732254.68058                                             NaN
# 7200   469060.57280  ['0x6a89228055c7c28430692e342f149f37462b478b']
# 7878        7.60121                                              []
# 8698        0.00000                                              []
# 13605       3.05949                                              []
#
#                                        pool  apyPct1D  ...    sigma  count  \
# 302    5fd328af-4203-471b-bd16-1705c726d926   0.36297  ...  0.28971    183
# 7164   56c9a12e-7d67-403e-94fa-acba39f4bbae  -0.96530  ...  0.14952    162
# 7165   e4637e67-357f-4f78-8d78-d626d809df6d  -0.52777  ...  0.45019    162
# 7199   f769a248-2c60-4ef0-b84b-084711c9624d       NaN  ...  3.74330    168
# 7200   661f5b9b-ea9d-4e47-a179-701c7ebbb028       NaN  ...  3.58295    168
# 7878   6ac49604-7002-4cea-8d5c-230c3231ab68   0.04997  ...  0.16710     60
# 8698   dd738877-28a8-40f5-b4a7-b2e8ff7159d1   0.00000  ...  0.00129     60
# 13605  a3212a53-9000-4aec-ab55-dd8f57ac809a  -0.46363  ...  0.14123     43
#
#        outlier                                   underlyingTokens il7d  \
# 302      False                                                NaN  NaN
# 7164     False     ['0x0655977feb2f289a4ab78af67bab0d17aab84367']  NaN
# 7165     False  ['0x1cb3c1c1e0f61770c224a66bb251c59f2c37ab91',...  NaN
# 7199      True     ['0xf939e0a03fb07f59a73314e73794be0e57ac1b4e']  NaN
# 7200      True  ['0x729908238075f050fa25ab8e50051d28acae0588',...  NaN
# 7878     False     ['0x0655977feb2f289a4ab78af67bab0d17aab84367']  NaN
# 8698     False  ['0x2d883d70aa9931a0c5514ac38c7db9237653acac',...  NaN
# 13605    False     ['0x0655977feb2f289a4ab78af67bab0d17aab84367']  NaN
#
#       apyBase7d  apyMean30d  volumeUsd1d  volumeUsd7d  apyBaseInception
# 302         NaN     1.23906          NaN          NaN               NaN
# 7164        NaN     9.36447          NaN          NaN               NaN
# 7165        NaN     5.62512          NaN          NaN               NaN
# 7199        NaN  1893.25343          NaN          NaN               NaN
# 7200        NaN   995.54283          NaN          NaN               NaN
# 7878        NaN     9.07149          NaN          NaN               NaN
# 8698        NaN     0.00055          NaN          NaN               NaN
# 13605       NaN     5.90391          NaN          NaN               NaN
#
# [8 rows x 28 columns]
